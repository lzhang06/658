# %%
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
import pandas as pd
import os, sys, email
import numpy as np 
# Plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns; sns.set_style('whitegrid')
#import plotly
#plotly.offline.init_notebook_mode()
#import plotly.graph_objs as go
import wordcloud

# Network analysis
import networkx as nx
# NLP
from nltk.tokenize.regexp import RegexpTokenizer

from subprocess import check_output

#unique words analysis
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import brown
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to /Users/Lucinda/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Read the data into a DataFrame
emails_df = pd.read_csv('/Users/Lucinda/Desktop/emails.csv')

emails_df.head()
# Out:
#                        file                                            message
# 0     allen-p/_sent_mail/1.  Message-ID: <18782981.1075855378110.JavaMail.e...
# 1    allen-p/_sent_mail/10.  Message-ID: <15464986.1075855378456.JavaMail.e...
# 2   allen-p/_sent_mail/100.  Message-ID: <24216240.1075855687451.JavaMail.e...
# 3  allen-p/_sent_mail/1000.  Message-ID: <13505866.1075863688222.JavaMail.e...
# 4  allen-p/_sent_mail/1001.  Message-ID: <30922949.1075863688243.JavaMail.e...

# %%
## Helper functions
def get_text_from_email(msg):
    '''To get the content from email objects'''
    parts = []
    for part in msg.walk():
        if part.get_content_type() == 'text/plain':
            parts.append( part.get_payload() )
    return ''.join(parts)

def split_email_addresses(line):
    '''To separate multiple email addresses'''
    if line:
        addrs = line.split(',')
        addrs = frozenset(map(lambda x: x.strip(), addrs))
    else:
        addrs = None
    return addrs

# %%
# Parse the emails into a list email objects
messages = list(map(email.message_from_string, emails_df['message']))
emails_df.drop('message', axis=1, inplace=True)
# Get fields from parsed email objects
keys = messages[0].keys()
for key in keys:
    emails_df[key] = [doc[key] for doc in messages]
# Parse content from emails
emails_df['content'] = list(map(get_text_from_email, messages))
# Split multiple email addresses
emails_df['From'] = emails_df['From'].map(split_email_addresses)
emails_df['To'] = emails_df['To'].map(split_email_addresses)

# Extract the root of 'file' as 'user'
emails_df['user'] = emails_df['file'].map(lambda x:x.split('/')[0])
del messages

# %% [markdown]
# ### Name Search

# %%
index_list = list(grouped_by_keypeople.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5d452c454966> in <module>()
# ----> 1 index_list = list(grouped_by_keypeople.index)
#
# NameError: name 'grouped_by_keypeople' is not defined

# %%
index_list[:5]
# Out:
# ['allen-p', 'arnold-j', 'arora-h', 'badeer-r', 'bailey-s']

# %%
for each in index_list:
    if each[0]=='j':
        print(each)
# Out:
# jones-t

# %% [markdown]
# ### Word Cloud of Mann

# %%
mann_k = ' '.join(mann_k)

# %%
__file__ =  '/Users/Lucinda/Desktop/'
d = path.dirname(__file__)

Mann_mask = imread(path.join(d, "/Users/Lucinda/Desktop/Kay3.png"))

# %%
wc = wordcloud.WordCloud(width=800, 
                         background_color = 'white',
                         height=600, 
                         max_words=500,
                         mask = Mann_mask,
                         stopwords=ENGLISH_STOP_WORDS).generate(mann_k)

# %%
# store to file
wc.to_file(path.join(d, "Mann_mask.png"))

# show
fig, ax = plt.subplots(figsize=(16, 12))
plt.imshow(wc)
plt.axis("off")
plt.figure()
plt.imshow(Mann_mask, cmap=plt.cm.gray)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Sara

# %%
for each in index_list:
    if each[0]=='s':
        #print(each)
# Out:
#   File "<ipython-input-404-e1a654bf659e>", line 3
#     #print(each)
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
sara_s = grouped_by_keypeople.ix['shackleton-s']

# %%
sara_s = ' '.join(sara_s)

# %%
__file__ =  '/Users/Lucinda/Desktop/'
d = path.dirname(__file__)

Sara_mask = imread(path.join(d, "/Users/Lucinda/Desktop/Sara3.jpg"))

# %%
wc = wordcloud.WordCloud(width=800, 
                         background_color = 'white',
                         height=600, 
                         max_words=500,
                         mask = Sara_mask,
                         stopwords=ENGLISH_STOP_WORDS).generate(sara_s)

# %%
# store to file
wc.to_file(path.join(d, "Sara_mask.png"))

# show
fig, ax = plt.subplots(figsize=(16, 12))
plt.imshow(wc)
plt.axis("off")
plt.figure()
plt.imshow(Sara_mask, cmap=plt.cm.gray)
plt.axis("off")
plt.show()

# %%
jones_t= grouped_by_keypeople.ix['jones-t']

# %%
jones_t = ' '.join(jones_t)

# %%
__file__ =  '/Users/Lucinda/Desktop/'
d = path.dirname(__file__)

Jones_mask = imread(path.join(d, "/Users/Lucinda/Desktop/Jone2.png"))

# %%
wc = wordcloud.WordCloud(width=800, 
                         background_color = 'white',
                         height=600, 
                         max_words=500,
                         mask = Jones_mask,
                         stopwords=ENGLISH_STOP_WORDS).generate(jones_t)

# %%
# store to file
wc.to_file(path.join(d, "Jones_mask.png"))

# show
fig, ax = plt.subplots(figsize=(16, 12))
plt.imshow(wc)
plt.axis("off")
plt.figure()
plt.imshow(Jones_mask, cmap=plt.cm.gray)
plt.axis("off")
plt.show()

# %%
#sns.pairplot(grouped_by_people.reset_index(), hue='user')

# %%
def replace_all(eg):
    rep = {"(":"",
       ")":"",
      "{":"",
      "}":"",
      "'":"",
        '"':"",
      "frozenset":""}
    for i,j in rep.items():
        eg = eg.replace(i,j)
    return eg

emails_df['Subject'] = emails_df['Subject'].apply(lambda x : replace_all(str(x)))

# %%
subjects = ' '.join(emails_df['Subject'])

# %%
fig, ax = plt.subplots(figsize=(16, 12))
wc = wordcloud.WordCloud(width=800, 
                         height=600, 
                         max_words=200,
                         stopwords=ENGLISH_STOP_WORDS).generate(subjects)
ax.imshow(wc)
ax.axis("off")
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
contents = ' '.join(emails_df['content'])
fig, ax = plt.subplots(figsize=(16, 12))
wc = wordcloud.WordCloud(width=800, 
                         height=600, 
                         max_words=200,
                         stopwords=ENGLISH_STOP_WORDS).generate(contents)
ax.imshow(wc)
ax.axis("off")
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
# Read the whole text.
Text = ' '.join(unique_words_df['Words'])

# %%
from os import path
from scipy.misc import imread
#import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS

__file__ =  '/Users/Lucinda/Desktop/'
d = path.dirname(__file__)



# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
Enron_mask = imread(path.join(d, "/Users/Lucinda/Desktop/EnronF2.png"))
#Enron_mask = Enron_mask.resize((980,1080), Image.ANTIALIAS) 

# generate word cloud
wc = wordcloud.WordCloud(background_color= 'white',
                         width=1200, 
                         height=900, 
                         max_words=3500,
                         mask=Enron_mask,
                         stopwords=ENGLISH_STOP_WORDS)
wc.generate(Text)

# %%
# store to file
wc.to_file(path.join(d, "enron1.png"))

# show
fig, ax = plt.subplots(figsize=(16, 12))
plt.imshow(wc)
plt.axis("off")
plt.figure()
plt.imshow(Enron_mask, cmap=plt.cm.gray)
plt.axis("off")
plt.show()

# %%
plt.imshow(Enron_mask, cmap=plt.cm.gray)

# %% [markdown]
# ### Unique Words

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import brown
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/Lucinda/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
emails_df1 = pd.read_csv('/Users/Lucinda/Desktop/emails.csv')

# %%
messageList = emails_df1['message'].tolist()

# %%
bodyList = []

#Janky first attempt at a split!
for message in messageList:
    #Split at the filename
    firstSplit = message.split("X-FileName: ", 1)[1]
    #Get everything after the file extension
    secondSplit = firstSplit.split(".")
    #Some error checking if the file type isn't included
    if len(secondSplit) > 1:
        secondSplit = secondSplit[1]
    body =  ''.join(secondSplit)[4:]
    bodyList.append(body)

# %%
#Join all of this text together
textBlob = ''.join(bodyList)

textTokenized = word_tokenize(textBlob)
textFreqDist = FreqDist(textTokenized)

# %%
uniquenessList = []

#Compare the occurance of a word to its occurance in the Brown Dataset
for word in textFreqDist:
    brownOccurances = brownFreqDist[word]
    textOccurances = textFreqDist[word]
    if brownOccurances > 5 and textOccurances > 5 and word.isalpha():
        uniquenessList.append((word, np.log10(float(textOccurances) / float(brownOccurances))))

# %%
uniquenessList.sort(key=lambda tup: -tup[1])

for i in range(2000):
    print("(%s, %f)" % (uniquenessList[i][0], uniquenessList[i][1]))
# Out:
# (attached, 2.856221)
# (schedules, 2.831678)
# (awarded, 2.580522)
# (deals, 2.552344)
# (draft, 2.490427)
# (requested, 2.431096)
# (please, 2.381901)
# (document, 2.376998)
# (revised, 2.375435)
# (web, 2.371683)
# (reminder, 2.359124)
# (meter, 2.285557)
# (executed, 2.248499)
# (confirmation, 2.210662)
# (comments, 2.201761)
# (confirm, 2.178797)
# (guys, 2.176381)
# (access, 2.169282)
# (regarding, 2.164502)
# (discuss, 2.163502)
# (s, 2.151871)
# (trading, 2.145507)
# (pipeline, 2.143535)
# (request, 2.125315)
# (copy, 2.123680)
# (pricing, 2.118217)
# (documents, 2.112182)
# (trades, 2.111337)
# (inform, 2.108178)
# (print, 2.103424)
# (listing, 2.101354)
# (schedule, 2.098740)
# (review, 2.050739)
# (agreements, 2.016755)
# (latest, 1.995259)
# (message, 1.994812)
# (summary, 1.992280)
# (weekend, 1.989746)
# (confidential, 1.988262)
# (presentations, 1.982271)
# (ensure, 1.981705)
# (thanks, 1.981292)
# (posted, 1.970178)
# (thru, 1.966728)
# (meeting, 1.962182)
# (scheduled, 1.962170)
# (format, 1.954778)
# (announce, 1.948847)
# (signature, 1.947760)
# (files, 1.945620)
# (trader, 1.945099)
# (entity, 1.943989)
# (tickets, 1.942717)
# (link, 1.938895)
# (send, 1.938439)
# (contracts, 1.938269)
# (resume, 1.934183)
# (advise, 1.931684)
# (presentation, 1.924436)
# (revisions, 1.913814)
# (tomorrow, 1.907633)
# (responding, 1.907590)
# (version, 1.902475)
# (pending, 1.891298)
# (reviewed, 1.891237)
# (turbine, 1.878905)
# (wholesale, 1.877536)
# (deadline, 1.867271)
# (deal, 1.857459)
# (booked, 1.857332)
# (users, 1.846131)
# (detected, 1.840942)
# (invite, 1.834247)
# (utilities, 1.825148)
# (dated, 1.824708)
# (commodity, 1.818603)
# (contract, 1.815356)
# (issues, 1.810884)
# (file, 1.810266)
# (transmission, 1.804906)
# (approval, 1.803645)
# (am, 1.799951)
# (calendar, 1.792892)
# (regards, 1.787359)
# (holiday, 1.785330)
# (disregard, 1.785330)
# (copies, 1.782950)
# (requesting, 1.782652)
# (list, 1.776133)
# (respond, 1.775038)
# (termination, 1.774517)
# (hour, 1.770801)
# (filing, 1.768521)
# (bankruptcy, 1.767156)
# (equity, 1.765562)
# (attend, 1.762039)
# (versions, 1.757565)
# (call, 1.755713)
# (phone, 1.752760)
# (mail, 1.751967)
# (following, 1.749345)
# (currently, 1.744063)
# (computer, 1.738537)
# (credit, 1.736894)
# (below, 1.736589)
# (delivery, 1.733662)
# (gas, 1.732800)
# (sending, 1.730260)
# (reviewing, 1.729974)
# (lunch, 1.728723)
# (folks, 1.722451)
# (discussed, 1.721367)
# (sent, 1.716866)
# (participate, 1.713720)
# (signing, 1.713611)
# (analyst, 1.711204)
# (counsel, 1.711063)
# (assets, 1.710182)
# (agreement, 1.706444)
# (execute, 1.705130)
# (yesterday, 1.701994)
# (caps, 1.700415)
# (approve, 1.698970)
# (analysts, 1.684247)
# (mailing, 1.682371)
# (weekly, 1.681618)
# (distribute, 1.681241)
# (negotiated, 1.678648)
# (signed, 1.677064)
# (forgot, 1.670040)
# (confirmed, 1.667920)
# (invitation, 1.664172)
# (received, 1.662642)
# (conference, 1.660094)
# (launch, 1.659916)
# (contact, 1.657936)
# (requests, 1.656646)
# (coordinate, 1.653213)
# (today, 1.651681)
# (tonight, 1.642673)
# (interview, 1.641654)
# (employees, 1.638489)
# (participants, 1.634909)
# (reporting, 1.629290)
# (facility, 1.626993)
# (meetings, 1.624724)
# (reliable, 1.622779)
# (entities, 1.618524)
# (your, 1.616304)
# (implementation, 1.615424)
# (customer, 1.615131)
# (forward, 1.612231)
# (outline, 1.611900)
# (directory, 1.611268)
# (delay, 1.610762)
# (execution, 1.608526)
# (ticket, 1.608125)
# (cancel, 1.605151)
# (filed, 1.602389)
# (remind, 1.602060)
# (corporate, 1.602060)
# (revision, 1.600701)
# (conversation, 1.595276)
# (address, 1.594235)
# (transport, 1.592300)
# (fuel, 1.589095)
# (traded, 1.585461)
# (week, 1.583837)
# (changes, 1.582740)
# (employee, 1.582158)
# (hi, 1.579784)
# (customers, 1.576629)
# (site, 1.575116)
# (businesses, 1.574945)
# (invited, 1.573586)
# (report, 1.573565)
# (accounting, 1.573065)
# (alternate, 1.572449)
# (response, 1.569723)
# (changed, 1.568202)
# (traders, 1.567298)
# (approved, 1.566437)
# (attending, 1.565129)
# (vacation, 1.560136)
# (arrange, 1.559907)
# (pleased, 1.558357)
# (enrollment, 1.556303)
# (resource, 1.556303)
# (compliance, 1.554287)
# (bids, 1.552263)
# (log, 1.550784)
# (sometime, 1.549672)
# (certificate, 1.547599)
# (release, 1.547409)
# (valuation, 1.544068)
# (sorry, 1.543551)
# (proceeding, 1.543033)
# (markets, 1.542866)
# (resigned, 1.542687)
# (appreciate, 1.540233)
# (note, 1.539353)
# (amendments, 1.536919)
# (environmental, 1.533300)
# (hey, 1.531479)
# (looks, 1.530659)
# (discussions, 1.529077)
# (sale, 1.528858)
# (thank, 1.527200)
# (fee, 1.526662)
# (information, 1.524104)
# (securities, 1.516866)
# (behalf, 1.516630)
# (submitted, 1.514737)
# (team, 1.513089)
# (hopefully, 1.511883)
# (agree, 1.508332)
# (amendment, 1.508090)
# (electricity, 1.505672)
# (metals, 1.505150)
# (negotiating, 1.505150)
# (litigation, 1.503057)
# (enclosed, 1.501433)
# (legal, 1.501364)
# (benjamin, 1.498311)
# (follows, 1.498042)
# (desk, 1.497355)
# (p, 1.492650)
# (calendars, 1.492633)
# (ns, 1.491362)
# (need, 1.491362)
# (reviews, 1.491362)
# (letter, 1.490201)
# (sheet, 1.488864)
# (forecast, 1.488551)
# (generators, 1.488237)
# (bid, 1.486237)
# (talked, 1.483563)
# (listed, 1.483003)
# (responses, 1.480212)
# (purchase, 1.478352)
# (stuff, 1.478025)
# (you, 1.477628)
# (accurate, 1.477535)
# (nomination, 1.477121)
# (energy, 1.473925)
# (spoke, 1.473277)
# (attach, 1.472965)
# (drafting, 1.469822)
# (curves, 1.469434)
# (messages, 1.467978)
# (dates, 1.467855)
# (morning, 1.466776)
# (risk, 1.465438)
# (booking, 1.464887)
# (paragraph, 1.464887)
# (prior, 1.463035)
# (check, 1.462568)
# (modifications, 1.462398)
# (monthly, 1.462398)
# (correct, 1.461244)
# (descriptions, 1.457882)
# (media, 1.454258)
# (relating, 1.454082)
# (canceled, 1.452298)
# (correctly, 1.449538)
# (missing, 1.448566)
# (date, 1.445498)
# (notice, 1.444257)
# (volumes, 1.443974)
# (current, 1.442962)
# (debt, 1.441151)
# (price, 1.440938)
# (clarify, 1.439940)
# (managing, 1.437354)
# (afternoon, 1.436643)
# (reflect, 1.435844)
# (represent, 1.434317)
# (advised, 1.433794)
# (reservations, 1.433147)
# (everyone, 1.432219)
# (prices, 1.431364)
# (btu, 1.428675)
# (topic, 1.427775)
# (noon, 1.427486)
# (conversations, 1.426511)
# (working, 1.426113)
# (project, 1.425268)
# (completed, 1.424076)
# (proposed, 1.422855)
# (resignation, 1.422074)
# (storage, 1.420238)
# (preliminary, 1.418439)
# (unavailable, 1.417353)
# (timing, 1.416489)
# (okay, 1.414973)
# (announcement, 1.414277)
# (generated, 1.411926)
# (proposal, 1.407992)
# (input, 1.406540)
# (discussing, 1.406540)
# (announcing, 1.405322)
# (lease, 1.404834)
# (holidays, 1.403692)
# (retail, 1.403121)
# (relates, 1.402261)
# (corrected, 1.399866)
# (viewing, 1.399674)
# (questions, 1.398064)
# (buys, 1.397940)
# (margin, 1.397940)
# (accomplishments, 1.397940)
# (k, 1.396199)
# (credits, 1.395451)
# (links, 1.392948)
# (photos, 1.392948)
# (allocation, 1.392800)
# (repairs, 1.391376)
# (package, 1.390935)
# (submitting, 1.389166)
# (sell, 1.388950)
# (strategy, 1.388360)
# (settlements, 1.386202)
# (status, 1.385404)
# (prepare, 1.383815)
# (utility, 1.382700)
# (comment, 1.378052)
# (fare, 1.377618)
# (owe, 1.376577)
# (experiencing, 1.375010)
# (wondering, 1.375010)
# (proposing, 1.371068)
# (me, 1.369320)
# (modified, 1.368930)
# (join, 1.368072)
# (regret, 1.367977)
# (internally, 1.367977)
# (card, 1.366782)
# (submit, 1.365904)
# (office, 1.363870)
# (sites, 1.361728)
# (financial, 1.361728)
# (find, 1.360593)
# (via, 1.360151)
# (resolutions, 1.358569)
# (peak, 1.356981)
# (article, 1.356981)
# (articles, 1.356827)
# (modify, 1.355388)
# (overall, 1.355388)
# (add, 1.354152)
# (focused, 1.353788)
# (details, 1.353028)
# (outlined, 1.352183)
# (recipient, 1.350802)
# (congratulations, 1.350802)
# (know, 1.350186)
# (consolidated, 1.348954)
# (rating, 1.348305)
# (assuming, 1.348190)
# (meters, 1.345997)
# (receive, 1.345786)
# (product, 1.345137)
# (subsidiary, 1.342423)
# (e, 1.341435)
# (interviewed, 1.340775)
# (privileged, 1.340444)
# (kidding, 1.339593)
# (named, 1.339357)
# (cash, 1.339120)
# (guarantee, 1.338014)
# (approaching, 1.338014)
# (failed, 1.336514)
# (packages, 1.335792)
# (prompt, 1.335184)
# (calculation, 1.334119)
# (agreeing, 1.333879)
# (market, 1.330283)
# (participating, 1.329059)
# (negotiation, 1.325652)
# (applications, 1.325516)
# (receiving, 1.325250)
# (charts, 1.324511)
# (earnings, 1.323306)
# (chart, 1.323158)
# (positions, 1.322985)
# (reply, 1.322711)
# (recurring, 1.322219)
# (discussion, 1.319571)
# (postpone, 1.319255)
# (topics, 1.315970)
# (sounds, 1.313100)
# (additions, 1.312929)
# (checked, 1.312778)
# (guy, 1.310298)
# (setup, 1.309098)
# (attorneys, 1.308209)
# (tentatively, 1.308209)
# (aware, 1.307445)
# (awaiting, 1.307190)
# (interested, 1.306986)
# (offer, 1.306693)
# (contains, 1.306143)
# (appoint, 1.304634)
# (resolve, 1.302697)
# (term, 1.301030)
# (manage, 1.301030)
# (lawyers, 1.300085)
# (issue, 1.298595)
# (settlement, 1.298517)
# (payment, 1.298153)
# (reports, 1.296090)
# (outstanding, 1.295121)
# (glad, 1.294698)
# (intervention, 1.293363)
# (eligible, 1.291623)
# (hiring, 1.290035)
# (items, 1.289725)
# (news, 1.289379)
# (profile, 1.289292)
# (deposit, 1.288796)
# (addressing, 1.288796)
# (restricted, 1.287802)
# (capacity, 1.287748)
# (fun, 1.286477)
# (liability, 1.285236)
# (gotten, 1.284431)
# (releases, 1.284431)
# (definitely, 1.283086)
# (month, 1.282605)
# (deliver, 1.282547)
# (discount, 1.282547)
# (released, 1.282256)
# (amended, 1.282007)
# (reservation, 1.281601)
# (preparing, 1.280827)
# (think, 1.279492)
# (contained, 1.278754)
# (on, 1.278122)
# (based, 1.277021)
# (o, 1.275223)
# (investments, 1.274927)
# (retention, 1.274927)
# (workshops, 1.274927)
# (conflicts, 1.273644)
# (addresses, 1.273277)
# (our, 1.272224)
# (merger, 1.272173)
# (freeze, 1.271067)
# (wanted, 1.270895)
# (quarter, 1.269238)
# (fix, 1.268845)
# (m, 1.268636)
# (closing, 1.267172)
# (appointments, 1.267172)
# (birthday, 1.267172)
# (language, 1.266633)
# (going, 1.266554)
# (crude, 1.266389)
# (offers, 1.265866)
# (notices, 1.265866)
# (mentioned, 1.265832)
# (quarterly, 1.265492)
# (sells, 1.264455)
# (map, 1.264455)
# (drives, 1.263241)
# (locations, 1.263241)
# (joining, 1.263241)
# (management, 1.259494)
# (expense, 1.259116)
# (model, 1.255899)
# (quick, 1.255627)
# (del, 1.255273)
# (issued, 1.252368)
# (hearings, 1.252246)
# (page, 1.251233)
# (mandatory, 1.251233)
# (elect, 1.249198)
# (closes, 1.247155)
# (timely, 1.247155)
# (final, 1.246839)
# (meet, 1.245612)
# (want, 1.244624)
# (hello, 1.243038)
# (appreciated, 1.241909)
# (proceed, 1.241657)
# (gather, 1.240549)
# (promotion, 1.240165)
# (houston, 1.237544)
# (thoughts, 1.237488)
# (introduce, 1.237361)
# (concerning, 1.236992)
# (lately, 1.236789)
# (purchases, 1.235213)
# (verified, 1.234686)
# (enrolled, 1.233278)
# (adjustments, 1.232996)
# (available, 1.231906)
# (helpful, 1.231329)
# (intend, 1.230449)
# (rotation, 1.225779)
# (item, 1.224839)
# (sure, 1.224581)
# (terminate, 1.224015)
# (getting, 1.222590)
# (trade, 1.221241)
# (gifts, 1.221058)
# (guarantees, 1.220762)
# (purchased, 1.220108)
# (relate, 1.219360)
# (get, 1.219010)
# (hardware, 1.218679)
# (addressed, 1.218176)
# (fine, 1.217729)
# (digital, 1.217484)
# (u, 1.216470)
# (handling, 1.215401)
# (recommendation, 1.215285)
# (distributed, 1.214059)
# (convenience, 1.214007)
# (j, 1.213075)
# (phones, 1.207980)
# (someone, 1.207571)
# (talk, 1.206230)
# (handle, 1.205654)
# (numbers, 1.205421)
# (assignments, 1.204120)
# (outlines, 1.204120)
# (delivered, 1.204120)
# (registration, 1.204120)
# (presents, 1.202472)
# (michael, 1.201645)
# (consumers, 1.201094)
# (generating, 1.200225)
# (let, 1.199429)
# (registered, 1.199374)
# (bidding, 1.196295)
# (focusing, 1.194977)
# (teams, 1.194136)
# (interviews, 1.194003)
# (buddy, 1.193553)
# (follow, 1.192780)
# (my, 1.192495)
# (focus, 1.191730)
# (transfer, 1.191408)
# (due, 1.190134)
# (ending, 1.189880)
# (process, 1.188182)
# (concerns, 1.186075)
# (master, 1.186030)
# (surgery, 1.185637)
# (definitions, 1.185637)
# (maps, 1.184910)
# (parties, 1.184355)
# (availability, 1.184286)
# (appointment, 1.184286)
# (max, 1.183270)
# (offering, 1.183270)
# (clean, 1.182754)
# (clause, 1.182478)
# (will, 1.181525)
# (buy, 1.179798)
# (exposure, 1.179552)
# (postponed, 1.179296)
# (potential, 1.178247)
# (power, 1.177612)
# (notes, 1.176599)
# (receipts, 1.176091)
# (next, 1.173733)
# (effective, 1.172032)
# (complaint, 1.171935)
# (plan, 1.171405)
# (talking, 1.170262)
# (we, 1.170222)
# (change, 1.169282)
# (interim, 1.168122)
# (mails, 1.167739)
# (believe, 1.167317)
# (presenting, 1.167317)
# (includes, 1.166989)
# (stack, 1.166331)
# (seats, 1.166331)
# (guess, 1.164565)
# (products, 1.163857)
# (loop, 1.163502)
# (starting, 1.162687)
# (incorporated, 1.162518)
# (lists, 1.162248)
# (resolved, 1.162081)
# (track, 1.161368)
# (see, 1.159463)
# (interviewing, 1.159223)
# (regulated, 1.159223)
# (group, 1.158826)
# (trip, 1.157468)
# (cap, 1.156347)
# (shipped, 1.156347)
# (propose, 1.155570)
# (launched, 1.154902)
# (notify, 1.153815)
# (created, 1.153344)
# (assist, 1.153228)
# (versus, 1.152967)
# (duplicate, 1.151268)
# (bet, 1.150756)
# (consultants, 1.150537)
# (potentially, 1.150537)
# (parking, 1.150112)
# (winner, 1.149988)
# (related, 1.149159)
# (looking, 1.148809)
# (consent, 1.147949)
# (suggestions, 1.147475)
# (contacts, 1.147367)
# (testing, 1.147096)
# (data, 1.146307)
# (financially, 1.146128)
# (commentary, 1.146128)
# (respective, 1.146128)
# (doc, 1.144574)
# (earlier, 1.142501)
# (hereby, 1.142233)
# (sold, 1.141483)
# (flowed, 1.140927)
# (couple, 1.139982)
# (client, 1.139879)
# (curve, 1.139879)
# (missed, 1.139879)
# (generator, 1.139429)
# (authorized, 1.139368)
# (preference, 1.139179)
# (description, 1.139179)
# (network, 1.138829)
# (unprecedented, 1.137584)
# (generate, 1.137173)
# (location, 1.136670)
# (investors, 1.136324)
# (executives, 1.135663)
# (responded, 1.135133)
# (clients, 1.133539)
# (recommend, 1.133539)
# (brief, 1.132751)
# (last, 1.132707)
# (l, 1.132340)
# (lawyer, 1.131455)
# (calculations, 1.130334)
# (traveling, 1.129486)
# (help, 1.127480)
# (install, 1.126294)
# (chris, 1.124939)
# (shopping, 1.124939)
# (indices, 1.123385)
# (prepared, 1.121734)
# (selling, 1.121422)
# (negotiate, 1.120574)
# (electronic, 1.118829)
# (have, 1.118110)
# (weeks, 1.117718)
# (error, 1.117639)
# (attendance, 1.116718)
# (virus, 1.116506)
# (sector, 1.116506)
# (wants, 1.116257)
# (violation, 1.115904)
# (manual, 1.113943)
# (congestion, 1.113943)
# (contractual, 1.113943)
# (automatically, 1.113943)
# (intended, 1.112456)
# (agreed, 1.111876)
# (kick, 1.111710)
# (sessions, 1.111366)
# (operational, 1.111263)
# (button, 1.110590)
# (spreads, 1.110590)
# (dinner, 1.110257)
# (yours, 1.109916)
# (complete, 1.109516)
# (hire, 1.109466)
# (originally, 1.108094)
# (informed, 1.107448)
# (staying, 1.106011)
# (rumor, 1.105510)
# (daily, 1.105371)
# (index, 1.105195)
# (just, 1.104963)
# (needs, 1.104388)
# (do, 1.103826)
# (negotiations, 1.103804)
# (sheets, 1.103804)
# (funny, 1.103219)
# (include, 1.103168)
# (nice, 1.102813)
# (prizes, 1.102662)
# (previous, 1.102529)
# (by, 1.101988)
# (tech, 1.101231)
# (ordering, 1.100900)
# (distribution, 1.100371)
# (yeah, 1.100371)
# (slide, 1.100371)
# (reflecting, 1.099965)
# (reference, 1.099753)
# (load, 1.099604)
# (doing, 1.099566)
# (newly, 1.099385)
# (adding, 1.098486)
# (flow, 1.097421)
# (survey, 1.097379)
# (previously, 1.096311)
# (quote, 1.095887)
# (referring, 1.094976)
# (additional, 1.094588)
# (defendants, 1.093422)
# (unable, 1.090428)
# (entered, 1.089400)
# (invites, 1.089400)
# (weather, 1.089034)
# (pick, 1.088297)
# (entering, 1.088136)
# (asking, 1.087739)
# (extend, 1.087278)
# (sign, 1.086814)
# (companies, 1.086196)
# (assess, 1.085172)
# (indicative, 1.085172)
# (commitment, 1.084714)
# (gift, 1.084630)
# (announced, 1.081642)
# (recent, 1.081198)
# (for, 1.080738)
# (recently, 1.079475)
# (conducting, 1.079181)
# (procedural, 1.079181)
# (inquiry, 1.079181)
# (diluted, 1.079181)
# (code, 1.078252)
# (ready, 1.076897)
# (commercial, 1.076802)
# (x, 1.076762)
# (processed, 1.076155)
# (applicable, 1.075141)
# (proposes, 1.073980)
# (expand, 1.073577)
# (geographic, 1.073107)
# (accounts, 1.072463)
# (pages, 1.072119)
# (promised, 1.071882)
# (buying, 1.071882)
# (paste, 1.071882)
# (marketing, 1.071540)
# (flights, 1.071356)
# (try, 1.071093)
# (pursuing, 1.071063)
# (priority, 1.071063)
# (inviting, 1.070038)
# (register, 1.069326)
# (able, 1.068151)
# (sources, 1.066665)
# (existing, 1.066326)
# (obligations, 1.065817)
# (travel, 1.065316)
# (assistant, 1.064874)
# (relevant, 1.064783)
# (utilize, 1.064458)
# (excited, 1.063154)
# (points, 1.062937)
# (officially, 1.062791)
# (communicate, 1.062148)
# (seeks, 1.060698)
# (liquids, 1.060698)
# (included, 1.060503)
# (directors, 1.059703)
# (happy, 1.059154)
# (visit, 1.057394)
# (name, 1.057345)
# (trying, 1.056390)
# (producers, 1.055269)
# (accidentally, 1.054358)
# (licensing, 1.054358)
# (scott, 1.053559)
# (requiring, 1.053559)
# (fees, 1.053476)
# (non, 1.053078)
# (bunch, 1.052852)
# (generation, 1.052729)
# (net, 1.051720)
# (requirements, 1.051269)
# (limit, 1.051153)
# (opportunities, 1.050584)
# (recommendations, 1.050274)
# (participation, 1.049974)
# (cell, 1.049814)
# (usage, 1.049772)
# (acquisition, 1.048305)
# (read, 1.048147)
# (graphic, 1.047924)
# (participated, 1.047425)
# (headlines, 1.046997)
# (weekends, 1.046997)
# (evaluating, 1.046997)
# (book, 1.046770)
# (dispatch, 1.046300)
# (estimates, 1.046300)
# (pursue, 1.045323)
# (assignment, 1.045197)
# (petition, 1.044017)
# (spoken, 1.043522)
# (announcements, 1.041393)
# (communicating, 1.041393)
# (offices, 1.041393)
# (finishing, 1.041393)
# (hope, 1.039605)
# (advice, 1.039109)
# (completing, 1.038345)
# (replacement, 1.037616)
# (provide, 1.037537)
# (this, 1.037035)
# (dad, 1.036096)
# (busy, 1.035913)
# (talented, 1.035716)
# (probe, 1.034762)
# (contractor, 1.034762)
# (bitch, 1.034762)
# (locate, 1.033926)
# (perspective, 1.032185)
# (monitoring, 1.032185)
# (flu, 1.031408)
# (rolling, 1.030877)
# (consumption, 1.030285)
# (calling, 1.029835)
# (internal, 1.029776)
# (account, 1.029765)
# (breakdown, 1.029071)
# (insights, 1.028876)
# (zone, 1.026793)
# (game, 1.026038)
# (entry, 1.025936)
# (instructions, 1.025306)
# (merge, 1.025306)
# (minute, 1.025306)
# (forum, 1.025306)
# (purchasing, 1.024824)
# (sooner, 1.024824)
# (whereby, 1.024442)
# (involvement, 1.022777)
# (person, 1.022139)
# (hear, 1.022134)
# (chance, 1.021663)
# (nominated, 1.021189)
# (partners, 1.021189)
# (appropriate, 1.019971)
# (obtaining, 1.018885)
# (assume, 1.018885)
# (business, 1.018285)
# (prompted, 1.018225)
# (consensus, 1.018225)
# (budget, 1.017316)
# (initial, 1.016296)
# (al, 1.015360)
# (economics, 1.015064)
# (using, 1.015013)
# (staff, 1.014736)
# (plans, 1.014364)
# (referral, 1.014240)
# (proceedings, 1.014240)
# (intends, 1.014240)
# (added, 1.013670)
# (transportation, 1.012935)
# (accessories, 1.012234)
# (intent, 1.012234)
# (exit, 1.012234)
# (edited, 1.012234)
# (showing, 1.010550)
# (hoping, 1.010017)
# (agent, 1.007825)
# (agrees, 1.007825)
# (comprehensive, 1.006804)
# (reflects, 1.005628)
# (environment, 1.005021)
# (event, 1.004799)
# (labeled, 1.004799)
# (candidate, 1.003815)
# (parent, 1.002886)
# (stating, 1.002706)
# (here, 1.000926)
# (luck, 1.000923)
# (coming, 1.000499)
# (opens, 1.000000)
# (pipes, 1.000000)
# (premium, 1.000000)
# (tips, 1.000000)
# (asked, 0.999454)
# (taking, 0.998508)
# (specified, 0.998446)
# (understand, 0.997775)
# (are, 0.996816)
# (supporting, 0.996771)
# (segment, 0.995635)
# (prefer, 0.995147)
# (cover, 0.995037)
# (projects, 0.994860)
# (retaining, 0.993751)
# (calls, 0.993121)
# (withdrawal, 0.992701)
# (licenses, 0.992701)
# (original, 0.992343)
# (criteria, 0.992031)
# (application, 0.990965)
# (start, 0.990593)
# (permitting, 0.990240)
# (begin, 0.989005)
# (investment, 0.988746)
# (yes, 0.988386)
# (cargo, 0.987411)
# (continue, 0.987232)
# (provisions, 0.986427)
# (already, 0.985935)
# (including, 0.985539)
# (ask, 0.985511)
# (slot, 0.985277)
# (company, 0.983984)
# (choosing, 0.983913)
# (refer, 0.983610)
# (talks, 0.982774)
# (revenue, 0.982271)
# (drinks, 0.981860)
# (analysis, 0.981097)
# (give, 0.980943)
# (changing, 0.980829)
# (delivering, 0.980256)
# (consistent, 0.979353)
# (look, 0.979268)
# (books, 0.979150)
# (set, 0.979047)
# (pass, 0.979006)
# (leaving, 0.978761)
# (answers, 0.978761)
# (savings, 0.978716)
# (coverage, 0.978637)
# (firm, 0.978352)
# (printed, 0.977724)
# (minus, 0.977724)
# (greetings, 0.977724)
# (exhibits, 0.977724)
# (fill, 0.977724)
# (supplier, 0.977724)
# (ph, 0.977724)
# (structured, 0.977724)
# (connection, 0.977392)
# (rejected, 0.977030)
# (session, 0.976579)
# (el, 0.975432)
# (candidates, 0.975311)
# (assign, 0.975176)
# (returning, 0.973128)
# (separately, 0.972416)
# (exciting, 0.972171)
# (names, 0.971776)
# (continues, 0.971547)
# (zero, 0.970037)
# (provided, 0.968978)
# (consulting, 0.968842)
# (go, 0.968796)
# (continental, 0.966759)
# (gathering, 0.966142)
# (suspension, 0.966142)
# (capture, 0.965451)
# (opportunity, 0.964879)
# (enjoy, 0.964002)
# (panel, 0.963483)
# (shortly, 0.962676)
# (mapping, 0.961082)
# (us, 0.960770)
# (split, 0.960629)
# (allow, 0.960233)
# (reserve, 0.959428)
# (julie, 0.959041)
# (flash, 0.958814)
# (acceptable, 0.958814)
# (executive, 0.958607)
# (floating, 0.958245)
# (attended, 0.958245)
# (order, 0.957821)
# (like, 0.956106)
# (security, 0.955302)
# (should, 0.954623)
# (protests, 0.954243)
# (consultation, 0.954243)
# (renewal, 0.954243)
# (compiled, 0.954243)
# (pop, 0.954243)
# (is, 0.953497)
# (heads, 0.953119)
# (pretty, 0.952435)
# (has, 0.951920)
# (replace, 0.951014)
# (protest, 0.950026)
# (per, 0.949272)
# (absolutely, 0.948847)
# (peer, 0.948168)
# (together, 0.947503)
# (communications, 0.947294)
# (switching, 0.947294)
# (calculating, 0.947294)
# (golf, 0.947088)
# (suggest, 0.947034)
# (physical, 0.946837)
# (appears, 0.946125)
# (mailed, 0.945099)
# (associate, 0.944952)
# (celebration, 0.944483)
# (estimate, 0.944230)
# (suggestion, 0.944192)
# (valued, 0.943777)
# (alumni, 0.943385)
# (noticed, 0.942504)
# (rice, 0.942384)
# (remaining, 0.942311)
# (compression, 0.942008)
# (consultant, 0.942008)
# (managers, 0.942008)
# (anyone, 0.941653)
# (pleasure, 0.941608)
# (accomplishment, 0.940232)
# (form, 0.940059)
# (heard, 0.939742)
# (identify, 0.939135)
# (responsibilities, 0.938520)
# (sadness, 0.937852)
# (offset, 0.937852)
# (works, 0.937595)
# (critical, 0.937276)
# (paying, 0.937209)
# (mark, 0.937046)
# (inquiries, 0.936868)
# (position, 0.936255)
# (good, 0.935650)
# (press, 0.935214)
# (pipe, 0.934498)
# (extended, 0.934498)
# (support, 0.934218)
# (about, 0.934137)
# (reserved, 0.934124)
# (days, 0.933524)
# (located, 0.931807)
# (benefits, 0.931735)
# (refund, 0.931735)
# (number, 0.931363)
# (key, 0.931157)
# (late, 0.930132)
# (et, 0.929419)
# (totals, 0.929419)
# (ad, 0.929419)
# (volume, 0.928851)
# (insert, 0.927449)
# (recall, 0.927449)
# (got, 0.927294)
# (lengthy, 0.927090)
# (assigned, 0.926032)
# (picking, 0.925754)
# (unit, 0.925683)
# (move, 0.925366)
# (technology, 0.925240)
# (installation, 0.925140)
# (events, 0.925098)
# (messenger, 0.924279)
# (figured, 0.924279)
# (matters, 0.923794)
# (improve, 0.923483)
# (wanting, 0.922985)
# (transmitted, 0.922985)
# (obligation, 0.922985)
# (payroll, 0.922985)
# (electric, 0.921839)
# (explore, 0.920819)
# (prospective, 0.920819)
# (excerpt, 0.920819)
# (demand, 0.919796)
# (departure, 0.918770)
# (disagree, 0.918330)
# (structure, 0.917754)
# (newest, 0.917330)
# (g, 0.916454)
# (clearing, 0.916454)
# (edition, 0.916098)
# (create, 0.915966)
# (evening, 0.915562)
# (selected, 0.915386)
# (associated, 0.915374)
# (resources, 0.914989)
# (partnership, 0.914989)
# (hesitate, 0.913814)
# (vote, 0.913814)
# (day, 0.913783)
# (references, 0.913151)
# (share, 0.912948)
# (significantly, 0.912566)
# (rates, 0.911523)
# (attorney, 0.911363)
# (anticipation, 0.911158)
# (hearing, 0.910877)
# (stranded, 0.910777)
# (sincerely, 0.910777)
# (select, 0.910114)
# (cd, 0.909823)
# (charges, 0.909080)
# (identified, 0.908951)
# (weird, 0.908485)
# (commodities, 0.908230)
# (deserved, 0.907590)
# (done, 0.907492)
# (flowing, 0.906272)
# (mistake, 0.906272)
# (putting, 0.906095)
# (interesting, 0.905730)
# (put, 0.904454)
# (legislation, 0.904269)
# (lot, 0.903944)
# (cookies, 0.903090)
# (season, 0.903090)
# (collecting, 0.903090)
# (competitive, 0.901335)
# (flight, 0.900723)
# (accepting, 0.900497)
# (waiting, 0.900119)
# (activities, 0.899773)
# (coal, 0.899684)
# (finance, 0.899573)
# (to, 0.898940)
# (rate, 0.898652)
# (everyday, 0.898542)
# (insurance, 0.898344)
# (spot, 0.898302)
# (solutions, 0.897437)
# (forget, 0.897016)
# (suggested, 0.895791)
# (seeking, 0.895623)
# (confusion, 0.895623)
# (welcome, 0.895423)
# (arena, 0.895265)
# (cable, 0.895265)
# (allows, 0.894433)
# (take, 0.894371)
# (met, 0.894366)
# (involving, 0.893106)
# (occur, 0.892871)
# (indicating, 0.892790)
# (floor, 0.892658)
# (numerous, 0.892568)
# (rough, 0.892366)
# (specifically, 0.891508)
# (transition, 0.891049)
# (providing, 0.890961)
# (poll, 0.890856)
# (detail, 0.890856)
# (earliest, 0.890573)
# (remove, 0.889785)
# (exemption, 0.889302)
# (really, 0.889251)
# (pursuant, 0.888783)
# (threshold, 0.888367)
# (retain, 0.888026)
# (garage, 0.887296)
# (formerly, 0.887296)
# (arrives, 0.887296)
# (individuals, 0.887186)
# (compensation, 0.886822)
# (assessment, 0.886245)
# (whoever, 0.886057)
# (delayed, 0.885361)
# (cool, 0.885215)
# (basketball, 0.884607)
# (inquire, 0.884607)
# (bachelor, 0.884607)
# (arriving, 0.884607)
# (host, 0.884607)
# (can, 0.883956)
# (alternative, 0.883494)
# (organize, 0.883256)
# (save, 0.882469)
# (recommending, 0.882240)
# (satellite, 0.882240)
# (granting, 0.882240)
# (workshop, 0.882240)
# (from, 0.881989)
# (handled, 0.881692)
# (ahead, 0.881652)
# (warning, 0.881592)
# (luncheon, 0.881310)
# (privileges, 0.880814)
# (tool, 0.880814)
# (trigger, 0.879860)
# (proxy, 0.879178)
# (planning, 0.876630)
# (pig, 0.875061)
# (farewell, 0.875061)
# (capabilities, 0.875061)
# (semester, 0.875061)
# (emergency, 0.874318)
# (airport, 0.873535)
# (financing, 0.873355)
# (system, 0.873248)
# (coordination, 0.873127)
# (up, 0.872850)
# (printing, 0.871832)
# (assigning, 0.871832)
# (soon, 0.870527)
# (setting, 0.870209)
# (describing, 0.869922)
# (responsible, 0.869727)
# (boss, 0.869232)
# (exhibit, 0.869232)
# (benefit, 0.869045)
# (helping, 0.868431)
# (work, 0.867781)
# (pay, 0.867248)
# (sleeve, 0.867092)
# (discrepancy, 0.867092)
# (testimony, 0.866978)
# (capability, 0.866709)
# (merchant, 0.866287)
# (volunteer, 0.865301)
# (periodically, 0.865301)
# (colleague, 0.865301)
# (happening, 0.864596)
# (crisis, 0.864337)
# (scope, 0.863102)
# (services, 0.863023)
# (n, 0.862696)
# (subscribers, 0.862472)
# (pulling, 0.862131)
# (directions, 0.861335)
# (procedures, 0.861074)
# (efforts, 0.860927)
# (impact, 0.860561)
# (currency, 0.860338)
# (conjunction, 0.860338)
# (decreased, 0.860338)
# (night, 0.860229)
# (speaking, 0.859855)
# (direct, 0.859292)
# (months, 0.858671)
# (marked, 0.858042)
# (misleading, 0.857332)
# (at, 0.856316)
# (assistants, 0.856234)
# (new, 0.856002)
# (checks, 0.855911)
# (gets, 0.855317)
# (shows, 0.854241)
# (bills, 0.854241)
# (profits, 0.853872)
# (proposals, 0.853572)
# (pull, 0.853531)
# (shower, 0.853293)
# (make, 0.853226)
# (heading, 0.853031)
# (diamond, 0.852785)
# (organizing, 0.852785)
# (roll, 0.852336)
# (ratings, 0.851937)
# (anything, 0.851695)
# (catch, 0.850831)
# (employment, 0.850346)
# (standpoint, 0.849844)
# (having, 0.849743)
# (hours, 0.849003)
# (entries, 0.848351)
# (helps, 0.847095)
# (resulting, 0.846538)
# (extra, 0.846337)
# (plants, 0.846148)
# (held, 0.845802)
# (collect, 0.845098)
# (super, 0.845098)
# (screens, 0.845098)
# (incurred, 0.845098)
# (whichever, 0.845098)
# (austin, 0.845098)
# (adjust, 0.845098)
# (statistics, 0.845098)
# (out, 0.844684)
# (performance, 0.844589)
# (baby, 0.844096)
# (arrive, 0.842505)
# (path, 0.842269)
# (expecting, 0.841638)
# (extension, 0.841638)
# (through, 0.841247)
# (partner, 0.841203)
# (regulation, 0.840644)
# (null, 0.840299)
# (answer, 0.840172)
# (speak, 0.839992)
# (with, 0.839659)
# (problem, 0.839512)
# (valid, 0.839421)
# (wedding, 0.839242)
# (dramatically, 0.838849)
# (handles, 0.838149)
# (bill, 0.838100)
# (enjoyed, 0.837411)
# (themes, 0.837273)
# (producer, 0.837273)
# (thereof, 0.837273)
# (thinking, 0.836891)
# (rental, 0.836746)
# (ability, 0.836632)
# (telephone, 0.836024)
# (accordance, 0.835691)
# (evaluate, 0.835447)
# (target, 0.835338)
# (temporary, 0.835294)
# (kids, 0.835294)
# (spelled, 0.834633)
# (thinks, 0.834172)
# (summer, 0.833366)
# (delighted, 0.833307)
# (be, 0.832973)
# (export, 0.832509)
# (drop, 0.832292)
# (swing, 0.831976)
# (masters, 0.831976)
# (publishing, 0.831596)
# (blank, 0.831596)
# (bring, 0.831538)
# (significant, 0.831170)
# (supply, 0.830249)
# (preparation, 0.829899)
# (contracted, 0.829304)
# (enter, 0.828891)
# (portions, 0.827839)
# (keep, 0.827839)
# (training, 0.827237)
# (courtesy, 0.827000)
# (plant, 0.826852)
# (party, 0.826615)
# (bottom, 0.825633)
# (continuing, 0.825330)
# (affect, 0.825148)
# (ignore, 0.825050)
# (downtown, 0.824967)
# (any, 0.824490)
# (licensed, 0.823909)
# (catching, 0.823909)
# (visiting, 0.823909)
# (promoted, 0.823909)
# (decision, 0.823726)
# (view, 0.822506)
# (probably, 0.821406)
# (idea, 0.821228)
# (charging, 0.821186)
# (commencing, 0.821186)
# (provision, 0.820663)
# (maintenance, 0.820160)
# (professionals, 0.819544)
# (been, 0.819459)
# (goes, 0.818508)
# (feeds, 0.818446)
# (initiated, 0.818446)
# (fixed, 0.817877)
# (lending, 0.817660)
# (dessert, 0.817660)
# (plus, 0.817529)
# (remember, 0.817249)
# (correspondence, 0.816904)
# (voice, 0.816740)
# (test, 0.816548)
# (totally, 0.815940)
# (respect, 0.815843)
# (moving, 0.815251)
# (containing, 0.815135)
# (passes, 0.814149)
# (decided, 0.814096)
# (leave, 0.814053)
# (use, 0.813648)
# (owned, 0.812913)
# (excluded, 0.812913)
# (parameters, 0.812913)
# (pro, 0.812913)
# (documented, 0.812913)
# (overnight, 0.812913)
# (sponsor, 0.812913)
# (permits, 0.811674)
# (settle, 0.811458)
# (forming, 0.811320)
# (conduct, 0.811087)
# (cluster, 0.810336)
# (solution, 0.810073)
# (organization, 0.809770)
# (evaluation, 0.809668)
# (replacing, 0.809185)
# (advance, 0.808932)
# (h, 0.808534)
# (jointly, 0.808114)
# (published, 0.808006)
# (goals, 0.807873)
# (anyway, 0.807064)
# (sentence, 0.804981)
# (retained, 0.803705)
# (anticipate, 0.803705)
# (terms, 0.803591)
# (penalty, 0.803262)
# (count, 0.802564)
# (creating, 0.802420)
# (bought, 0.802040)
# (text, 0.801632)
# (cycle, 0.801632)
# (routes, 0.801632)
# (tank, 0.801632)
# (rumors, 0.801632)
# (above, 0.801014)
# (effort, 0.801001)
# (short, 0.800769)
# (considering, 0.800659)
# (controls, 0.799341)
# (paper, 0.799297)
# (does, 0.798985)
# (orders, 0.798865)
# (bored, 0.798355)
# (juan, 0.798355)
# (spin, 0.798355)
# (wire, 0.798355)
# (mention, 0.797960)
# (time, 0.797941)
# (supposed, 0.797747)
# (recover, 0.797456)
# (tentative, 0.797037)
# (associates, 0.797037)
# (sample, 0.796793)
# (service, 0.796156)
# (exceptionally, 0.795880)
# (detailed, 0.795880)
# (exclusive, 0.795880)
# (payments, 0.795525)
# (investigation, 0.794857)
# (crazy, 0.794857)
# (senior, 0.794857)
# (summarized, 0.793946)
# (initiative, 0.793703)
# (strips, 0.793391)
# (wrong, 0.793043)
# (biggest, 0.792975)
# (did, 0.792875)
# (wish, 0.792392)
# (uncertainty, 0.790740)
# (designated, 0.790740)
# (album, 0.790050)
# (seller, 0.790050)
# (workout, 0.790050)
# (venture, 0.789432)
# (perform, 0.788022)
# (developments, 0.787911)
# (starts, 0.787392)
# (efficiently, 0.787106)
# (required, 0.786814)
# (yet, 0.786704)
# (codes, 0.786584)
# (keeping, 0.786515)
# (question, 0.786243)
# (if, 0.785790)
# (further, 0.785722)
# (amazing, 0.785330)
# (conflict, 0.785056)
# (immediately, 0.784577)
# (performed, 0.784312)
# (r, 0.783828)
# (called, 0.783176)
# (sick, 0.782388)
# (initially, 0.782154)
# (until, 0.781903)
# (definition, 0.780052)
# (back, 0.779573)
# (exotic, 0.778151)
# (shipping, 0.778151)
# (fabulous, 0.778151)
# (football, 0.778151)
# (wait, 0.778151)
# (mornings, 0.778151)
# (requirement, 0.778151)
# (assemble, 0.778151)
# (configuration, 0.778151)
# (sharing, 0.778151)
# (directing, 0.778151)
# (great, 0.777716)
# (cards, 0.776136)
# (remote, 0.775883)
# (forms, 0.775292)
# (strategic, 0.774993)
# (formally, 0.774111)
# (screen, 0.773604)
# (job, 0.773565)
# (title, 0.772474)
# (assumptions, 0.771811)
# (thought, 0.771805)
# (quantities, 0.771521)
# (gang, 0.771521)
# (records, 0.770933)
# (scanned, 0.770852)
# (fake, 0.770852)
# (legislative, 0.770852)
# (seeing, 0.770510)
# (worry, 0.770182)
# (pushing, 0.769551)
# (groups, 0.769377)
# (decrease, 0.768391)
# (push, 0.768258)
# (subject, 0.768146)
# (useful, 0.768051)
# (myself, 0.767932)
# (gadgets, 0.767686)
# (bullets, 0.767686)
# (opening, 0.767558)
# (mine, 0.766967)
# (diverse, 0.766870)
# (conservation, 0.766870)
# (some, 0.766453)
# (ken, 0.765917)
# (open, 0.765917)
# (rationale, 0.765917)
# (clip, 0.765917)
# (worked, 0.765529)
# (tells, 0.765186)
# (script, 0.764787)
# (bit, 0.764317)
# (competitors, 0.763428)
# (coalition, 0.763428)
# (future, 0.763230)
# (criminal, 0.762804)
# (arrangements, 0.762639)
# (hate, 0.762357)
# (comfortable, 0.762212)
# (giving, 0.761239)
# (suggesting, 0.761118)
# (cake, 0.761118)
# (year, 0.760757)
# (annual, 0.760682)
# (basis, 0.760488)
# (wishes, 0.759668)
# (actively, 0.759668)
# (resent, 0.759668)
# (decide, 0.759668)
# (approximately, 0.759402)
# (loan, 0.758846)
# (dispute, 0.758556)
# (facing, 0.758556)
# (would, 0.757701)
# (acquire, 0.756157)
# (tremendous, 0.756081)
# (utilized, 0.755875)
# (case, 0.755369)
# (explaining, 0.755288)
# (objections, 0.755288)
# (covering, 0.754921)
# (interest, 0.753560)
# (locker, 0.753328)
# (arguments, 0.753328)
# (touch, 0.752446)
# (past, 0.751871)
# (charge, 0.751859)
# (anonymous, 0.751822)
# (activity, 0.751783)
# (bother, 0.750999)
# (removing, 0.750123)
# (kindly, 0.750123)
# (favorite, 0.748944)
# (rush, 0.748188)
# (tournament, 0.748188)
# (background, 0.747956)
# (natural, 0.747392)
# (wonderful, 0.747016)
# (needed, 0.746443)
# (injection, 0.745967)
# (rent, 0.745967)
# (issuance, 0.745967)
# (educate, 0.745967)
# (exchanged, 0.745967)
# (skiing, 0.745967)
# (verbal, 0.745967)
# (manager, 0.745713)
# (production, 0.745665)
# (match, 0.745151)
# (v, 0.744727)
# (retire, 0.744727)
# (expenses, 0.744543)
# (post, 0.744523)
# (results, 0.744319)
# (expanded, 0.744293)
# (content, 0.744071)
# (acquiring, 0.743937)
# (still, 0.743682)
# (finish, 0.743389)
# (that, 0.742808)
# (understanding, 0.741991)
# (exact, 0.741823)
# (players, 0.741722)
# (limits, 0.741325)
# (consideration, 0.741168)
# (win, 0.741080)
# (firms, 0.741080)
# (breach, 0.740363)
# (loads, 0.740363)
# (sticking, 0.740363)
# (operations, 0.739422)
# (letting, 0.739087)
# (perfect, 0.737631)
# (oil, 0.737444)
# (raise, 0.737315)
# (secured, 0.736759)
# (restore, 0.735954)
# (projection, 0.735954)
# (tools, 0.735693)
# (flag, 0.735399)
# (earn, 0.735399)
# (assisting, 0.734686)
# (speakers, 0.734686)
# (bargain, 0.734686)
# (assistance, 0.734423)
# (problems, 0.734408)
# (tough, 0.733732)
# (downstairs, 0.733732)
# (titled, 0.733732)
# (amounts, 0.733124)
# (dealing, 0.732020)
# (unfortunately, 0.731906)
# (joined, 0.731819)
# (how, 0.731564)
# (stocks, 0.731499)
# (successfully, 0.731355)
# (transferred, 0.730727)
# (minor, 0.730727)
# (entertainment, 0.730727)
# (an, 0.730476)
# (cleaned, 0.730378)
# (backing, 0.730378)
# (accompany, 0.730378)
# (investigating, 0.730378)
# (so, 0.729793)
# (vince, 0.729459)
# (either, 0.729382)
# (accept, 0.729255)
# (proud, 0.729165)
# (beginning, 0.729145)
# (cost, 0.728301)
# (run, 0.728277)
# (specific, 0.727471)
# (ago, 0.727330)
# (asks, 0.726999)
# (declines, 0.726999)
# (manure, 0.726999)
# (domain, 0.726999)
# (await, 0.726999)
# (borrow, 0.726999)
# (very, 0.726350)
# (spend, 0.725973)
# (type, 0.725503)
# (adjustment, 0.725445)
# (few, 0.725324)
# (things, 0.725299)
# (friend, 0.724953)
# (off, 0.724314)
# (hr, 0.723104)
# (manipulation, 0.723104)
# (incredibly, 0.723104)
# (accommodate, 0.723104)
# (mentions, 0.723104)
# (informal, 0.722451)
# (return, 0.721536)
# (searching, 0.721058)
# (fast, 0.720689)
# (linked, 0.720159)
# (committed, 0.720159)
# (indicated, 0.720159)
# (instructed, 0.720159)
# (complaints, 0.720159)
# (entertaining, 0.720159)
# (care, 0.719904)
# (hired, 0.719331)
# (actually, 0.718912)
# (possible, 0.718497)
# (functions, 0.718432)
# (provides, 0.717855)
# (analytical, 0.717855)
# (inventory, 0.717453)
# (exchange, 0.717195)
# (supports, 0.716003)
# (burn, 0.716003)
# (representing, 0.716003)
# (what, 0.715539)
# (contain, 0.714143)
# (residing, 0.713210)
# (excess, 0.713210)
# (seize, 0.713210)
# (contemplating, 0.713210)
# (cuts, 0.713210)
# (andrew, 0.713210)
# (wires, 0.712131)
# (point, 0.711967)
# (search, 0.711935)
# (shoot, 0.711651)
# (damaged, 0.711204)
# (billions, 0.711204)
# (quickly, 0.710526)
# (briefly, 0.710251)
# (hurricane, 0.709694)
# (babe, 0.709694)
# (categories, 0.709694)
# (now, 0.709032)
# (turkey, 0.708515)
# (therein, 0.708515)
# (jokes, 0.708515)
# (models, 0.708113)
# (else, 0.707764)
# (exception, 0.707570)
# (attempted, 0.706795)
# (duke, 0.706795)
# (loading, 0.706795)
# (electrical, 0.706458)
# (accepted, 0.706149)
# (debts, 0.706149)
# (agency, 0.705130)
# (debate, 0.704365)
# (reads, 0.704365)
# (right, 0.703761)
# (basically, 0.703291)
# (solve, 0.703291)
# (addition, 0.703231)
# (saving, 0.703087)
# (ownership, 0.702900)
# (describes, 0.702900)
# (expectations, 0.702730)
# (research, 0.702511)
# (region, 0.702385)
# (bringing, 0.701250)
# (holding, 0.700304)
# (success, 0.699903)
# (remainder, 0.698970)
# (inactive, 0.698970)
# (hunt, 0.698970)
# (privacy, 0.698970)
# (covers, 0.698970)
# (visits, 0.698970)
# (switched, 0.698970)
# (mess, 0.698970)
# (linking, 0.698970)
# (anticipated, 0.698970)
# (experienced, 0.698970)
# (understands, 0.698970)
# (stay, 0.696658)
# (minutes, 0.695857)
# (all, 0.695337)
# (dedicated, 0.695177)
# (implications, 0.695004)
# (units, 0.694958)
# (bold, 0.694814)
# (close, 0.694493)
# (joint, 0.694493)
# (nonspecific, 0.694374)
# (feature, 0.694249)
# (performing, 0.693830)
# (campus, 0.693674)
# (several, 0.693172)
# (outside, 0.693140)
# (best, 0.692739)
# (guaranteed, 0.692237)
# (again, 0.691837)
# (successful, 0.691593)
# (attempting, 0.691351)
# (tell, 0.691121)
# (investigate, 0.691001)
# (counterparts, 0.691001)
# (alert, 0.691001)
# (transfers, 0.691001)
# (require, 0.690814)
# (not, 0.689407)
# (sales, 0.689062)
# (obtain, 0.688505)
# (well, 0.688186)
# (logs, 0.687975)
# (junk, 0.687975)
# (round, 0.687232)
# (unless, 0.686760)
# (extremely, 0.686636)
# (generosity, 0.686381)
# (en, 0.686381)
# (industry, 0.685558)
# (operating, 0.684763)
# (totaling, 0.684247)
# (extends, 0.684247)
# (delivers, 0.684247)
# (bucks, 0.684247)
# (pleading, 0.684247)
# (maybe, 0.683683)
# (colleagues, 0.683595)
# (billion, 0.683279)
# (making, 0.682658)
# (grab, 0.682371)
# (spending, 0.681682)
# (owed, 0.681241)
# (deemed, 0.681241)
# (lobby, 0.681241)
# (tennis, 0.681241)
# (qualified, 0.680487)
# (lots, 0.679947)
# (projected, 0.679947)
# (end, 0.679646)
# (rated, 0.679226)
# (pants, 0.679226)
# (douglass, 0.679226)
# (controller, 0.679226)
# (convenient, 0.678767)
# (explanation, 0.678285)
# (kay, 0.677781)
# (spread, 0.677519)
# (presented, 0.677251)
# (directly, 0.676856)
# (kicking, 0.676694)
# (license, 0.676694)
# (worthwhile, 0.676694)
# (policy, 0.676488)
# (resolution, 0.675263)
# (maximum, 0.675245)
# (freezing, 0.675167)
# (defeated, 0.675167)
# (developing, 0.674932)
# (joke, 0.674611)
# (finished, 0.674323)
# (conferences, 0.673942)
# (rules, 0.673725)
# (running, 0.673523)
# (involved, 0.673416)
# (apply, 0.673416)
# (answering, 0.673416)
# (govern, 0.673416)
# (bullet, 0.673416)
# (free, 0.673060)
# (expansion, 0.672294)
# (alleged, 0.672098)
# (sponsored, 0.672098)
# (adds, 0.672098)
# (offered, 0.671987)
# (mix, 0.671386)
# (flexibility, 0.670941)
# (regularly, 0.670415)
# (deposits, 0.669007)
# (refuses, 0.669007)
# (f, 0.669007)
# (consolidation, 0.669007)
# (margins, 0.669007)
# (assessments, 0.669007)
# (someplace, 0.669007)
# (nights, 0.669007)
# (costs, 0.668830)
# (games, 0.667877)
# (underlying, 0.667453)
# (border, 0.667453)
# (everything, 0.667327)
# (base, 0.667299)
# (separate, 0.667039)
# (t, 0.666177)
# (seasonal, 0.665112)
# (arrangement, 0.664421)
# (owns, 0.664208)
# (letters, 0.663578)
# (tax, 0.663415)
# (friends, 0.663224)
# (external, 0.663197)
# (pools, 0.662758)
# (analyze, 0.662758)
# (progress, 0.661970)
# (enjoying, 0.661646)
# (show, 0.660852)
# (premier, 0.660574)
# (crack, 0.660052)
# (facilities, 0.659916)
# (purposes, 0.659599)
# (lined, 0.659203)
# (d, 0.658965)
# (says, 0.658488)
# (being, 0.658199)
# (hold, 0.658040)
# (puts, 0.658011)
# (framework, 0.657577)
# (arising, 0.657577)
# (approximate, 0.657577)
# (fixing, 0.657577)
# (opinion, 0.657215)
# (administrator, 0.656418)
# (portion, 0.656315)
# (duties, 0.656042)
# (closed, 0.655935)
# (a, 0.655629)
# (occurs, 0.654996)
# (saved, 0.654333)
# (moved, 0.654012)
# (peers, 0.653213)
# (inception, 0.653213)
# (tease, 0.653213)
# (manipulate, 0.653213)
# (accommodations, 0.653213)
# (coordinates, 0.653213)
# (mentioning, 0.653213)
# (aggregate, 0.653213)
# (restriction, 0.653213)
# (tagged, 0.653213)
# (kent, 0.653213)
# (diagram, 0.653213)
# (throws, 0.653213)
# (floors, 0.653213)
# (building, 0.652004)
# (adjusted, 0.651748)
# (contributions, 0.651545)
# (bad, 0.650485)
# (tied, 0.650365)
# (systems, 0.649833)
# (communication, 0.649596)
# (balance, 0.648902)
# (loaded, 0.648803)
# (reception, 0.648103)
# (specifications, 0.647817)
# (causing, 0.647817)
# (comparing, 0.647817)
# (larry, 0.647817)
# (maine, 0.647817)
# (tie, 0.646872)
# (consider, 0.646705)
# (numbering, 0.646264)
# (interstate, 0.646264)
# (role, 0.645724)
# (stock, 0.645596)
# (concern, 0.645262)
# (liquidation, 0.645095)
# (restrictions, 0.644183)
# (shut, 0.642594)
# (eliminate, 0.641932)
# (member, 0.641431)
# (applicant, 0.640978)
# (festivities, 0.640978)
# (installed, 0.640623)
# (materials, 0.640594)
# (shares, 0.640438)
# (average, 0.640405)
# (under, 0.640117)
# (pitch, 0.639849)
# (succession, 0.639486)
# (guest, 0.639384)
# (top, 0.639272)
# (hard, 0.639131)
# (happen, 0.638410)
# (standard, 0.638035)
# (c, 0.637374)
# (carryover, 0.636822)
# (convert, 0.636822)
# (evidenced, 0.636822)
# (pigs, 0.636822)
# (uh, 0.636822)
# (chocolate, 0.636822)
# (hint, 0.636822)
# (introducing, 0.636822)
# (speech, 0.636274)
# (pressing, 0.635484)
# (amount, 0.635460)
# (paid, 0.635206)
# (rely, 0.634245)
# (sponsors, 0.633468)
# (fantastic, 0.633468)
# (declined, 0.632874)
# (anniversary, 0.632023)
# (supportive, 0.632023)
# (conversion, 0.632023)
# (certified, 0.632023)
# (endeavor, 0.632023)
# (exclude, 0.632023)
# (delta, 0.632023)
# (easiest, 0.632023)
# (attacks, 0.630705)
# (treating, 0.630705)
# (spaces, 0.630705)
# (publications, 0.629498)
# (surrounding, 0.629334)
# (recruits, 0.628389)
# (withheld, 0.628389)
# (analyzing, 0.628389)
# (officer, 0.628136)
# (whether, 0.627853)
# (regular, 0.627465)
# (breaking, 0.627366)
# (hitting, 0.626884)
# (implied, 0.626884)
# (town, 0.626457)
# (cents, 0.626419)
# (adopt, 0.626419)
# (fully, 0.625827)
# (line, 0.625809)
# (representation, 0.625541)
# (filter, 0.625541)
# (ours, 0.625541)
# (enables, 0.625541)
# (the, 0.625372)
# (engage, 0.624724)

# %%
unique_words_df = pd.DataFrame(uniquenessList,columns = ['Words', 'Count'])

# %%
unique_words_df.shape
# Out:
# (6984, 2)

# %%
words_df = pd.DataFrame(list(textFreqDist.items()),columns = ['Words', 'Count'])

# %%
words_df.head()
# Out:
#        Words  Count
# 0      alcoa      1
# 1     CTC/PX      1
# 2  countless      3
# 3     Surely      4
# 4        GOT     19

# %%
words_df2 = words_df.sort(columns = 'Count',ascending=False )
# Out:
# /Users/Lucinda/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
words_df2.head()
# Out:
#        Words    Count
# 111612    --  1287526
# 4815       ,   590460
# 47667      :   328054
# 37770    the   295318
# 26320      @   286557

# %%
uniquenessList = []

#Compare the occurance of a word to its occurance in the Brown Dataset
for word in textFreqDist:
    brownOccurances = brownFreqDist[word]
    textOccurances = textFreqDist[word]
    if brownOccurances > 5 and textOccurances > 5 and word.isalpha():
        uniquenessList.append((word, textOccurances))

# %%
uniquenessList.sort(key=lambda tup: -tup[1])

for i in range(200):
    print("(%s, %f)" % (uniquenessList[i][0], uniquenessList[i][1]))
# Out:
# (the, 295318.000000)
# (to, 207274.000000)
# (on, 127893.000000)
# (and, 120982.000000)
# (of, 118732.000000)
# (for, 114277.000000)
# (a, 104960.000000)
# (you, 98695.000000)
# (is, 90825.000000)
# (in, 77758.000000)
# (by, 67105.000000)
# (that, 58596.000000)
# (this, 56030.000000)
# (have, 51740.000000)
# (with, 50388.000000)
# (are, 43619.000000)
# (be, 43410.000000)
# (we, 39246.000000)
# (at, 38588.000000)
# (your, 38151.000000)
# (will, 34099.000000)
# (from, 33302.000000)
# (it, 29144.000000)
# (me, 27642.000000)
# (as, 24501.000000)
# (our, 23433.000000)
# (not, 22548.000000)
# (has, 21816.000000)
# (my, 20531.000000)
# (an, 20107.000000)
# (attached, 17954.000000)
# (was, 17405.000000)
# (do, 17311.000000)
# (been, 16312.000000)
# (or, 16130.000000)
# (about, 15596.000000)
# (would, 15535.000000)
# (know, 15297.000000)
# (am, 14952.000000)
# (please, 14938.000000)
# (all, 14880.000000)
# (out, 14665.000000)
# (meeting, 14574.000000)
# (up, 14103.000000)
# (can, 13565.000000)
# (but, 13540.000000)
# (if, 13422.000000)
# (today, 12735.000000)
# (following, 12409.000000)
# (get, 12402.000000)
# (new, 11736.000000)
# (like, 11678.000000)
# (need, 11160.000000)
# (see, 11145.000000)
# (just, 11104.000000)
# (call, 10712.000000)
# (so, 10655.000000)
# (week, 10548.000000)
# (deal, 10299.000000)
# (time, 10035.000000)
# (what, 9911.000000)
# (some, 9450.000000)
# (one, 9339.000000)
# (last, 9176.000000)
# (find, 9176.000000)
# (information, 8992.000000)
# (any, 8972.000000)
# (which, 8824.000000)
# (hour, 8554.000000)
# (i, 8347.000000)
# (think, 8241.000000)
# (should, 7999.000000)
# (list, 7943.000000)
# (below, 7906.000000)
# (there, 7877.000000)
# (had, 7690.000000)
# (sent, 7555.000000)
# (here, 7516.000000)
# (received, 7496.000000)
# (draft, 7424.000000)
# (going, 7371.000000)
# (they, 7116.000000)
# (good, 6950.000000)
# (schedules, 6787.000000)
# (through, 6737.000000)
# (now, 6724.000000)
# (these, 6600.000000)
# (request, 6539.000000)
# (report, 6518.000000)
# (did, 6480.000000)
# (awarded, 6471.000000)
# (send, 6422.000000)
# (message, 6324.000000)
# (were, 6311.000000)
# (review, 6294.000000)
# (their, 6198.000000)
# (morning, 6181.000000)
# (us, 6167.000000)
# (let, 6078.000000)
# (he, 6075.000000)
# (into, 5970.000000)
# (office, 5894.000000)
# (next, 5878.000000)
# (regarding, 5842.000000)
# (go, 5826.000000)
# (back, 5815.000000)
# (who, 5789.000000)
# (want, 5761.000000)
# (make, 5663.000000)
# (day, 5633.000000)
# (group, 5622.000000)
# (work, 5620.000000)
# (more, 5574.000000)
# (may, 5495.000000)
# (no, 5491.000000)
# (agreement, 5392.000000)
# (gas, 5351.000000)
# (deals, 5351.000000)
# (when, 5292.000000)
# (file, 5233.000000)
# (power, 5148.000000)
# (two, 5134.000000)
# (tomorrow, 5093.000000)
# (copy, 5052.000000)
# (changes, 5012.000000)
# (them, 4945.000000)
# (take, 4783.000000)
# (comments, 4774.000000)
# (forward, 4709.000000)
# (schedule, 4519.000000)
# (how, 4495.000000)
# (letter, 4483.000000)
# (over, 4478.000000)
# (sure, 4411.000000)
# (first, 4399.000000)
# (note, 4397.000000)
# (conference, 4389.000000)
# (well, 4375.000000)
# (other, 4341.000000)
# (still, 4334.000000)
# (issues, 4270.000000)
# (only, 4254.000000)
# (very, 4239.000000)
# (version, 4234.000000)
# (wanted, 4217.000000)
# (could, 4215.000000)
# (available, 4179.000000)
# (yesterday, 4179.000000)
# (help, 4171.000000)
# (business, 4099.000000)
# (discuss, 4080.000000)
# (got, 4077.000000)
# (number, 4030.000000)
# (working, 4028.000000)
# (great, 3986.000000)
# (asked, 3975.000000)
# (set, 3945.000000)
# (contract, 3922.000000)
# (his, 3850.000000)
# (use, 3848.000000)
# (its, 3805.000000)
# (look, 3804.000000)
# (revised, 3798.000000)
# (year, 3793.000000)
# (give, 3723.000000)
# (thanks, 3544.000000)
# (change, 3544.000000)
# (access, 3544.000000)
# (changed, 3515.000000)
# (put, 3507.000000)
# (questions, 3501.000000)
# (trading, 3495.000000)
# (credit, 3492.000000)
# (scheduled, 3483.000000)
# (latest, 3462.000000)
# (discussed, 3422.000000)
# (order, 3412.000000)
# (off, 3387.000000)
# (name, 3355.000000)
# (made, 3347.000000)
# (market, 3316.000000)
# (per, 3301.000000)
# (days, 3295.000000)
# (approval, 3245.000000)
# (being, 3241.000000)
# (requested, 3238.000000)
# (form, 3223.000000)
# (much, 3204.000000)
# (few, 3193.000000)
# (before, 3167.000000)
# (attend, 3122.000000)
# (s, 3121.000000)
# (system, 3107.000000)
# (right, 3099.000000)
# (document, 3097.000000)
# (under, 3087.000000)
# (thought, 3057.000000)
# (phone, 3056.000000)
# (does, 3053.000000)
# (plan, 3042.000000)

# %%
count = {}
for w in uniquedf.ix[:,0]:
    if w in count:
        count[w] += 1
    else:
        count[w] = 1
for word in count.items():
    print (word)
# Out:
# ('applicable', 1)
# ('contractor', 1)
# ('leaf', 1)
# ('naked', 1)
# ('use', 1)
# ('strip', 1)
# ('brutal', 1)
# ('june', 1)
# ('number', 1)
# ('packages', 1)
# ('leads', 1)
# ('postponed', 1)
# ('manual', 1)
# ('costume', 1)
# ('combinations', 1)
# ('tank', 1)
# ('whoever', 1)
# ('disposal', 1)
# ('suited', 1)
# ('maintaining', 1)
# ('everything', 1)
# ('camp', 1)
# ('managed', 1)
# ('picnic', 1)
# ('manufacturers', 1)
# ('pocket', 1)
# ('contrary', 1)
# ('midwest', 1)
# ('judy', 1)
# ('exceed', 1)
# ('deer', 1)
# ('reviews', 1)
# ('dividend', 1)
# ('feasible', 1)
# ('sole', 1)
# ('average', 1)
# ('classified', 1)
# ('enjoying', 1)
# ('asian', 1)
# ('admitted', 1)
# ('blood', 1)
# ('fighting', 1)
# ('uncertainty', 1)
# ('conspiracy', 1)
# ('memorable', 1)
# ('settlements', 1)
# ('invites', 1)
# ('fitness', 1)
# ('report', 1)
# ('ladies', 1)
# ('indications', 1)
# ('promptly', 1)
# ('late', 1)
# ('caused', 1)
# ('afterwards', 1)
# ('driven', 1)
# ('slate', 1)
# ('thursday', 1)
# ('effective', 1)
# ('medical', 1)
# ('widely', 1)
# ('formula', 1)
# ('seeking', 1)
# ('heightened', 1)
# ('garden', 1)
# ('coast', 1)
# ('leading', 1)
# ('assignment', 1)
# ('marketing', 1)
# ('analytical', 1)
# ('negotiations', 1)
# ('pops', 1)
# ('functional', 1)
# ('unlimited', 1)
# ('anew', 1)
# ('light', 1)
# ('camps', 1)
# ('nurse', 1)
# ('wave', 1)
# ('hundreds', 1)
# ('visitor', 1)
# ('steer', 1)
# ('pipes', 1)
# ('authorized', 1)
# ('minor', 1)
# ('guide', 1)
# ('arm', 1)
# ('allow', 1)
# ('exploded', 1)
# ('star', 1)
# ('sky', 1)
# ('credited', 1)
# ('functions', 1)
# ('army', 1)
# ('listened', 1)
# ('clarify', 1)
# ('flashed', 1)
# ('making', 1)
# ('added', 1)
# ('screens', 1)
# ('heat', 1)
# ('inaugural', 1)
# ('less', 1)
# ('capabilities', 1)
# ('misplaced', 1)
# ('realistically', 1)
# ('personnel', 1)
# ('investigate', 1)
# ('corridor', 1)
# ('host', 1)
# ('class', 1)
# ('halfway', 1)
# ('odor', 1)
# ('axe', 1)
# ('stricken', 1)
# ('policies', 1)
# ('officially', 1)
# ('intellectual', 1)
# ('yard', 1)
# ('damage', 1)
# ('unusually', 1)
# ('tournament', 1)
# ('in', 1)
# ('department', 1)
# ('spring', 1)
# ('determined', 1)
# ('contempt', 1)
# ('blast', 1)
# ('eat', 1)
# ('night', 1)
# ('fault', 1)
# ('nagging', 1)
# ('roger', 1)
# ('advisory', 1)
# ('registration', 1)
# ('allowed', 1)
# ('fourth', 1)
# ('or', 1)

# %% [markdown]
# ### word cloud

# %%
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS

d = path.dirname(__file__)

# Read the whole text.
text = open(path.join(d, 'alice.txt')).read()

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = imread(path.join(d, "alice_mask.png"))

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               stopwords=STOPWORDS.add("said"))
# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "alice.png"))

# show
plt.imshow(wc)
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray)
plt.axis("off")
plt.show()

# %%
f = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                              'foo', 'bar', 'foo', 'foo'],
                  'B' : ['one', 'one', 'two', 'three',
                              'two', 'two', 'one', 'three'],
                  'C' : np.random.randn(8),
                  'D' : np.random.randn(8)})

# %%
f
# Out:
#      A      B         C         D
# 0  foo    one  0.216158 -0.091090
# 1  bar    one -0.173265  0.238421
# 2  foo    two  0.738463  2.197395
# 3  bar  three  0.595438  2.319035
# 4  foo    two  0.189528  0.113226
# 5  bar    two -1.840963 -0.326461
# 6  foo    one -1.516118 -0.057337
# 7  foo  three  1.171348 -0.800614

# %%
grouped = f.groupby('A').agg({'B': lambda x: ' '.join(x)})

# %%
grouped
# Out:
#                          B
# A
# bar          one three two
# foo  one two two one three
